# %% [markdown]
# # Turtle Library

# %%
from turtle import *
s = Screen()
t = Turtle()


print(t.position())
done()
# Out:
# (0.00,0.00)

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 125644.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t=Turtle()
t.shape("turtle")
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 215030.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To draw line using Turtle library

# %%
from turtle import *
t=Turtle()
t.forward(150)         

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 130157.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾Turtle graphics with a specific angle

# %%
from turtle import *
t=Turtle()

t.forward(100) 
t.left(90)




done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 132550.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To move to another position

# %%
from turtle import *

t = Turtle()
t.goto(100, 100)  
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 172856.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *

t = Turtle()
t.pencolor("blue")
t.fillcolor("red")
t.pendown()

t.forward(100)     
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 180635.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To draw Triangle using Turtle library

# %%
from turtle import *
t=Turtle()

t.forward(100)
t.left(120)


t.forward(100)
t.left(120)


t.forward(100)
t.left(120)

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 132952.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To draw Square using Turtle library

# %%
from turtle import *
t=Turtle()
for _ in range(4):
    t.backward(100)
    t.right(90)
    

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 134447.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t=Turtle()
for _ in range(4):
    t.color("red","red")
    t.backward(100)
    t.right(90)
    

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 170407.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To draw Circle using Turtle library

# %%
from turtle import *
t=Turtle()

t.circle(50)



done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 182013.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t=Turtle()

t.circle(50,170)



done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 182448.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *

t = Turtle()

t.fillcolor("yellow")     

t.begin_fill()           

for _ in range(4):
    t.forward(100)
    t.right(90)

t.end_fill()            



done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 184752.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *            
t=Turtle()
t.speed(2)
for i in range(10):
   t.circle(5*i)
   t.circle(-5*i)
   t.right(i)
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 190459.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t=Turtle()
t.penup()
t.pendown()
t.pensize(10)
t.pencolor("pink")
t.forward(100)
t.backward(100)
t.right(90)
t.forward(100)
t.left(90)
t.forward(100)
t.backward(100)
t.right(90)
t.forward(100)
t.left(90)
t.forward(100)
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 185243.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t=Turtle()
# t.shape("turtle")
t.color("yellow")
t.width(5)
for i in range(40):
    t.forward(i*10)
    t.left(120)
    
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 220024.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *

t = Turtle()
t.speed(3)

for _ in range(5):
    t.color("red")
    t.forward(150)
    t.right(144)  
   

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 223535.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *

t = Turtle()
t.speed(0)
t.color("red")

for _ in range(36):
    t.circle(100)
    t.left(170)

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 223835.png" alt="شعار بايثون" width="500"/>
