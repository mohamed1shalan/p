# %% [markdown]
# # Turtle Library

# %%
from turtle import *
s = Screen()
t = Turtle()


print(t.position())
done()
# Out:
# (0.00,0.00)

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 125644.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t = Turtle()
t.shape("turtle")
done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from turtle import *
# ----> 2 t=Turtle()
#       3 t.shape("turtle")
#       4 done()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3845, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3843 if Turtle._screen is None:
#    3844     Turtle._screen = Screen()
# -> 3845 RawTurtle.__init__(self, Turtle._screen,
#    3846                    shape=shape,
#    3847                    undobuffersize=undobuffersize,
#    3848                    visible=visible)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2564, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2562 self._undobuffersize = undobuffersize
#    2563 self.undobuffer = Tbuffer(undobuffersize)
# -> 2564 self._update()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2667, in RawTurtle._update(self)
#    2665     return
#    2666 elif screen._tracing == 1:
# -> 2667     self._update_data()
#    2668     self._drawturtle()
#    2669     screen._update()                  # TurtleScreenBase
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2653, in RawTurtle._update_data(self)
#    2652 def _update_data(self):
# -> 2653     self.screen._incrementudc()
#    2654     if self.screen._updatecounter != 0:
#    2655         return
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:1283, in TurtleScreen._incrementudc(self)
#    1281 if not TurtleScreen._RUNNING:
#    1282     TurtleScreen._RUNNING = True
# -> 1283     raise Terminator
#    1284 if self._tracing > 0:
#    1285     self._updatecounter += 1
#
# Terminator:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 215030.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To draw line using Turtle library

# %%
from turtle import *
t = Turtle()
t.forward(150)

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 130157.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾Turtle graphics with a specific angle

# %%
from turtle import *
t = Turtle()

t.forward(100)
t.left(90)


done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 132550.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To move to another position

# %%
from turtle import *

t = Turtle()
t.goto(100, 100)
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 172856.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *

t = Turtle()
t.pencolor("blue")
t.fillcolor("red")
t.pendown()

t.forward(100)
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 180635.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To draw Triangle using Turtle library

# %%
from turtle import *
t = Turtle()

t.forward(100)
t.left(120)


t.forward(100)
t.left(120)


t.forward(100)
t.left(120)

done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from turtle import *
# ----> 2 t = Turtle()
#       4 t.forward(100)
#       5 t.left(120)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3845, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3843 if Turtle._screen is None:
#    3844     Turtle._screen = Screen()
# -> 3845 RawTurtle.__init__(self, Turtle._screen,
#    3846                    shape=shape,
#    3847                    undobuffersize=undobuffersize,
#    3848                    visible=visible)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2564, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2562 self._undobuffersize = undobuffersize
#    2563 self.undobuffer = Tbuffer(undobuffersize)
# -> 2564 self._update()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2667, in RawTurtle._update(self)
#    2665     return
#    2666 elif screen._tracing == 1:
# -> 2667     self._update_data()
#    2668     self._drawturtle()
#    2669     screen._update()                  # TurtleScreenBase
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2653, in RawTurtle._update_data(self)
#    2652 def _update_data(self):
# -> 2653     self.screen._incrementudc()
#    2654     if self.screen._updatecounter != 0:
#    2655         return
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:1283, in TurtleScreen._incrementudc(self)
#    1281 if not TurtleScreen._RUNNING:
#    1282     TurtleScreen._RUNNING = True
# -> 1283     raise Terminator
#    1284 if self._tracing > 0:
#    1285     self._updatecounter += 1
#
# Terminator:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 132952.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To draw Square using Turtle library

# %%
from turtle import *
t = Turtle()
for _ in range(4):
    t.backward(100)
    t.right(90)


done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 134447.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t = Turtle()
for _ in range(4):
    t.color("red", "red")
    t.backward(100)
    t.right(90)


done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 170407.png" alt="شعار بايثون" width="500"/>

# %% [markdown]
# ### 👾To draw Circle using Turtle library

# %%
from turtle import *
t = Turtle()

t.circle(50)


done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from turtle import *
# ----> 2 t = Turtle()
#       4 t.circle(50)
#       7 done()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3845, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3843 if Turtle._screen is None:
#    3844     Turtle._screen = Screen()
# -> 3845 RawTurtle.__init__(self, Turtle._screen,
#    3846                    shape=shape,
#    3847                    undobuffersize=undobuffersize,
#    3848                    visible=visible)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2564, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2562 self._undobuffersize = undobuffersize
#    2563 self.undobuffer = Tbuffer(undobuffersize)
# -> 2564 self._update()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2667, in RawTurtle._update(self)
#    2665     return
#    2666 elif screen._tracing == 1:
# -> 2667     self._update_data()
#    2668     self._drawturtle()
#    2669     screen._update()                  # TurtleScreenBase
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2653, in RawTurtle._update_data(self)
#    2652 def _update_data(self):
# -> 2653     self.screen._incrementudc()
#    2654     if self.screen._updatecounter != 0:
#    2655         return
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:1283, in TurtleScreen._incrementudc(self)
#    1281 if not TurtleScreen._RUNNING:
#    1282     TurtleScreen._RUNNING = True
# -> 1283     raise Terminator
#    1284 if self._tracing > 0:
#    1285     self._updatecounter += 1
#
# Terminator:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 182013.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t = Turtle()

t.circle(50, 170)


done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from turtle import *
# ----> 2 t = Turtle()
#       4 t.circle(50, 170)
#       7 done()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3845, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3843 if Turtle._screen is None:
#    3844     Turtle._screen = Screen()
# -> 3845 RawTurtle.__init__(self, Turtle._screen,
#    3846                    shape=shape,
#    3847                    undobuffersize=undobuffersize,
#    3848                    visible=visible)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2564, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2562 self._undobuffersize = undobuffersize
#    2563 self.undobuffer = Tbuffer(undobuffersize)
# -> 2564 self._update()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2667, in RawTurtle._update(self)
#    2665     return
#    2666 elif screen._tracing == 1:
# -> 2667     self._update_data()
#    2668     self._drawturtle()
#    2669     screen._update()                  # TurtleScreenBase
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2653, in RawTurtle._update_data(self)
#    2652 def _update_data(self):
# -> 2653     self.screen._incrementudc()
#    2654     if self.screen._updatecounter != 0:
#    2655         return
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:1283, in TurtleScreen._incrementudc(self)
#    1281 if not TurtleScreen._RUNNING:
#    1282     TurtleScreen._RUNNING = True
# -> 1283     raise Terminator
#    1284 if self._tracing > 0:
#    1285     self._updatecounter += 1
#
# Terminator:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 182448.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *

t = Turtle()

t.fillcolor("yellow")

t.begin_fill()

for _ in range(4):
    t.forward(100)
    t.right(90)

t.end_fill()


done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 from turtle import *
# ----> 3 t = Turtle()
#       5 t.fillcolor("yellow")
#       7 t.begin_fill()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3845, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3843 if Turtle._screen is None:
#    3844     Turtle._screen = Screen()
# -> 3845 RawTurtle.__init__(self, Turtle._screen,
#    3846                    shape=shape,
#    3847                    undobuffersize=undobuffersize,
#    3848                    visible=visible)
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2564, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2562 self._undobuffersize = undobuffersize
#    2563 self.undobuffer = Tbuffer(undobuffersize)
# -> 2564 self._update()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2667, in RawTurtle._update(self)
#    2665     return
#    2666 elif screen._tracing == 1:
# -> 2667     self._update_data()
#    2668     self._drawturtle()
#    2669     screen._update()                  # TurtleScreenBase
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2653, in RawTurtle._update_data(self)
#    2652 def _update_data(self):
# -> 2653     self.screen._incrementudc()
#    2654     if self.screen._updatecounter != 0:
#    2655         return
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\turtle.py:1283, in TurtleScreen._incrementudc(self)
#    1281 if not TurtleScreen._RUNNING:
#    1282     TurtleScreen._RUNNING = True
# -> 1283     raise Terminator
#    1284 if self._tracing > 0:
#    1285     self._updatecounter += 1
#
# Terminator:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 184752.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t = Turtle()
t.speed(2)
for i in range(10):
    t.circle(5*i)
    t.circle(-5*i)
    t.right(i)
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 190459.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t = Turtle()
t.penup()
t.pendown()
t.pensize(10)
t.pencolor("pink")
t.forward(100)
t.backward(100)
t.right(90)
t.forward(100)
t.left(90)
t.forward(100)
t.backward(100)
t.right(90)
t.forward(100)
t.left(90)
t.forward(100)
done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 185243.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *
t = Turtle()
# t.shape("turtle")
t.color("yellow")
t.width(5)
for i in range(40):
    t.forward(i*10)
    t.left(120)

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 220024.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *

t = Turtle()
t.speed(3)

for _ in range(5):
    t.color("red")
    t.forward(150)
    t.right(144)


done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 223535.png" alt="شعار بايثون" width="500"/>

# %%
from turtle import *

t = Turtle()
t.speed(0)
t.color("red")

for _ in range(36):
    t.circle(100)
    t.left(170)

done()

# %% [markdown]
# <img src="images\Screenshot 2025-02-22 223835.png" alt="شعار بايثون" width="500"/>
