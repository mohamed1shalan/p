# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (25.0.1)

# %%
# %pip install graphics.py

from graphics import *
# Out:
# Requirement already satisfied: graphics.py in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (5.0.1.post1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Graphics Library

# %% [markdown]
# ## 1.GraphWin

# %% [markdown]
# #### 👾GraphWin (title, width, height): class that implement a window where you can draw in, provide some graphical objects as Point, Line, Circle, Oval, Rectangle, Polygon, Text, Entry, Image

# %%
from graphics import *

win = GraphWin("My Window", 200, 200)

win.getMouse()       # or     win.checkMouse()
win.close()


# or


def main():
    win = GraphWin("My Window", 200, 200)
    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[1], line 5
#       1 from graphics import *
#       3 win = GraphWin("My Window", 200, 200)
# ----> 5 win.getMouse()       # or     win.checkMouse()
#       6 win.close()
#       9 # or
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python312\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# #### 👾setBackground(Color) to change the background color of the window

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)
    win.setBackground("yellow")

    win.getMouse()
    win.close()


main()

# %% [markdown]
# ## 2.Graphic objects

# %% [markdown]
# #### provided to draw in GraphWin as color, width, animation effects as:point – line – circle – oval – rectangle – polygon – text.

# %% [markdown]
# ### Point Methods

# %% [markdown]
# #### 👾plot(x , y , color) or Point(x , y) to draw a point

# %%
from graphics import *


def main():

    win = GraphWin("My Window", 500, 500)
    win.plot(45, 130, "red")

    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[1], line 13
#       9     win.getMouse()
#      10     win.close()
# ---> 13 main()
#
# Cell In[1], line 9, in main()
#       6 win = GraphWin("My Window", 500, 500)
#       7 win.plot(45, 130, "red")
# ----> 9 win.getMouse()
#      10 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %%
from graphics import *


def main():

    win = GraphWin("My Window", 500, 500)
    pt = Point(45, 130)
    pt.draw(win)

    win.getMouse()
    win.close()


main()

# %% [markdown]
# #### 👾setOutLine(color) to change the color of the point

# %%
from graphics import *


def main():

    win = GraphWin("My Window", 500, 500)
    pt = Point(45, 130)
    pt.setOutline("red")
    pt.draw(win)

    win.getMouse()
    win.close()


main()

# %% [markdown]
# ### Line Methods

# %% [markdown]
# #### 👾Line(point1, point2) : Constructs a line segment from point1 to point2.

# %%
from graphics import *


def main():

    win = GraphWin("My Window", 500, 500)
    pt1 = Point(10, 10)
    pt2 = Point(90, 90)

    line = Line(pt1, pt2)  # line = Line(Point(10,10),Point(90,90))

    line.setOutline("red")
    line.draw(win)

    win.getMouse()
    win.close()


main()

# %% [markdown]
# #### 👾setWidth(pixels) : Sets the width of the outline of the object to the desired number of pixels. (Does not work for Point.)

# %%
from graphics import *


def main():

    win = GraphWin("My Window", 500, 500)

    line = Line(Point(10, 10), Point(90, 90))
    line.setWidth(5)

    line.setOutline("red")
    line.draw(win)

    win.getMouse()
    win.close()


main()

# %% [markdown]
# #### 👾setArrow(endString) : Sets the arrowhead status of a line. Arrows may be drawn at either the point, the last point, or both. Possible values of endString are "first", "last", "both",and "none". The default setting is "none".

# %%
from graphics import *


def main():

    win = GraphWin("My Window", 500, 500)

    line = Line(Point(10, 10), Point(90, 90))
    line.setArrow("both")

    line.setOutline("red")
    line.draw(win)

    win.getMouse()
    win.close()


main()

# %% [markdown]
# ### Rectangle Methods

# %% [markdown]
# #### 👾Rectangle(point1 , point2): to draw a rectangle

# %%
from graphics import *


def main():

    win = GraphWin("My Window", 500, 500)

    reg = Rectangle(Point(10, 30), Point(40, 70))

    reg.setOutline("red")
    reg.draw(win)

    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[2], line 17
#      13     win.getMouse()
#      14     win.close()
# ---> 17 main()
#
# Cell In[2], line 13, in main()
#      10 reg.setOutline("red")
#      11 reg.draw(win)
# ---> 13 win.getMouse()
#      14 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# #### 👾setFill (color) : Sets the interior of the object to the given color.

# %%
from graphics import *


def main():

    win = GraphWin("My Window", 500, 500)

    reg = Rectangle(Point(10, 30), Point(40, 70))
    reg.setFill("red")
    reg.setOutline("black")
    reg.draw(win)

    win.getMouse()
    win.close()


main()

# %% [markdown]
# #### 👾getCenter( ) : Returns a clone of the center point of the rectangle.

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)

    reg = Rectangle(Point(10, 30), Point(40, 70))
    reg.setFill("red")
    reg.setOutline("black")
    reg.draw(win)

    center = reg.getCenter()
    print(center)

    win.getMouse()
    win.close()


main()

# %% [markdown]
# ### Polygon Methods

# %% [markdown]
# #### 👾Polygon(point1, point2, point3, ...) : Constructs a polygon with the given points as vertices. Also accepts a single parameter that is a list of the vertices.

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)

    pol = Polygon(Point(100, 200), Point(200, 100),
                  Point(300, 200), Point(250, 300))
    # or     pol = Polygon([Point(100, 200), Point(200, 100), Point(300, 200), Point(250, 300)])

    pol.setFill("red")
    pol.setOutline("black")
    pol.setWidth(3)
    pol.draw(win)

    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[7], line 20
#      16     win.getMouse()
#      17     win.close()
# ---> 20 main()
#
# Cell In[7], line 16, in main()
#      13 pol.setWidth(3)
#      14 pol.draw(win)
# ---> 16 win.getMouse()
#      17 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# ### Text Methods

# %% [markdown]
# #### 👾Text (anchorPoint, textString) : Constructs a text object that displays textString centered at anchorPoint. The text is displayed horizontally.

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)

    text = Text(Point(250, 250), "Hello World")
    text.draw(win)

    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[5], line 14
#      10     win.getMouse()
#      11     win.close()
# ---> 14 main()
#
# Cell In[5], line 10, in main()
#       7 text = Text(Point(250, 250), "Hello World")
#       8 text.draw(win)
# ---> 10 win.getMouse()
#      11 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# #### 👾getAnchor ( ) : Returns a clone of the anchor point.

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)

    text = Text(Point(100, 100), "Hello World")
    centerPoint = text.getAnchor()
    text.draw(win)
    print(centerPoint)

    win.getMouse()
    win.close()


main()
# Out:
# Point(100.0, 100.0)
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[6], line 16
#      12     win.getMouse()
#      13     win.close()
# ---> 16 main()
#
# Cell In[6], line 12, in main()
#       9 text.draw(win)
#      10 print(centerPoint)
# ---> 12 win.getMouse()
#      13 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# #### 👾setFace(family) : Changes the font face to the given family. Possible values are "helvetica", courier", "times roman", and "arial".

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)

    text = Text(Point(100, 100), "Hello World")
    text.setFace("arial")
    text.draw(win)

    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[1], line 15
#      11     win.getMouse()
#      12     win.close()
# ---> 15 main()
#
# Cell In[1], line 11, in main()
#       8 text.setFace("arial")
#       9 text.draw(win)
# ---> 11 win.getMouse()
#      12 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# #### 👾setSize(point) : Changes the font size to the given point size. Sizes from 5 to 36 points are legal.

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)

    text = Text(Point(250, 250), "Hello World")
    text.setSize(20)
    text.draw(win)

    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[1], line 15
#      11     win.getMouse()
#      12     win.close()
# ---> 15 main()
#
# Cell In[1], line 11, in main()
#       8 text.setSize(20)
#       9 text.draw(win)
# ---> 11 win.getMouse()
#      12 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# #### 👾setStyle(style) : Changes font to the given style. Possible values are: "normal", "bold", "italic", and "bold italic".

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)

    text = Text(Point(100, 100), "Hello World")
    text.setStyle("italic")
    text.draw(win)

    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[2], line 15
#      11     win.getMouse()
#      12     win.close()
# ---> 15 main()
#
# Cell In[2], line 11, in main()
#       8 text.setStyle("italic")
#       9 text.draw(win)
# ---> 11 win.getMouse()
#      12 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# #### 👾setTextColor(color) : Sets the color of the text to color. Note: setFill has the same effect.

# %%
from graphics import *


def main():
    win = GraphWin("My Window", 500, 500)

    text = Text(Point(100, 100), "Hello World")
    text.setTextColor("green")
    text.draw(win)

    win.getMouse()
    win.close()


main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# Cell In[3], line 15
#      11     win.getMouse()
#      12     win.close()
# ---> 15 main()
#
# Cell In[3], line 11, in main()
#       8 text.setTextColor("green")
#       9 text.draw(win)
# ---> 11 win.getMouse()
#      12 win.close()
#
# File c:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphics\__init__.py:316, in GraphWin.getMouse(self)
#     314 while self.mouseX == None or self.mouseY == None:
#     315     self.update()
# --> 316     if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317     time.sleep(.1) # give up thread
#     318 x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %% [markdown]
# ### Entry Methods

# %% [markdown]
# #### 👾Entry(centerPoint, width) : Constructs an Entry having the given center point and width. Thewidth is specified in number of characters of text that can be displayed.

# %%
from graphics import *

win = GraphWin("My Window", 500, 500)

text_Entry = Entry(Point(250, 250), 20)
text_Entry.draw(win)

win.getMouse()

entry = text_Entry.getText()
print(entry)

txt = Text(Point(400, 400), entry)
txt.draw(win)

win.getMouse()
win.close()
# Out:
# hallo
